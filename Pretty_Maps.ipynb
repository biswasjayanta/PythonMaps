# %% [markdown]
# Installation (Restart runtime after running the following cell)

# %%
#!pip install vpype
#!pip install git+https://github.com/abey79/vsketch#egg=vsketch
# !pip install git+https://github.com/abey79/vsketch.git
# !pip install git+https://github.com/marceloprates/prettymaps.git
# !pip install matplotlib --version=3.1.3

# !mkdir ../prints
# !mkdir ../assets
# !mkdir ../assets/Permanent_Marker/
# !wget -O ../assets/Permanent_Marker/PermanentMarker-Regular.ttf https://github.com/marceloprates/prettymaps/raw/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/abey79/vsketch.git
#   Cloning https://github.com/abey79/vsketch.git to /tmp/pip-req-build-rbzcgxwj
#   Running command git clone --filter=blob:none --quiet https://github.com/abey79/vsketch.git /tmp/pip-req-build-rbzcgxwj
#   Resolved https://github.com/abey79/vsketch.git to commit a7de220624d55fdf0b544f6a346f095b909f8727
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.20.1 in /usr/local/lib/python3.10/dist-packages (from vsketch==1.0.0a0) (1.22.4)
# Collecting pnoise>=0.2.0
#   Downloading pnoise-0.2.0-py3-none-any.whl (13 kB)
# Collecting watchfiles>=0.12
#   Downloading watchfiles-0.19.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.1 MB/s eta 0:00:00
# Collecting PySide6>=6.3.2
#   Downloading PySide6-6.5.0-cp37-abi3-manylinux_2_28_x86_64.whl (6.7 kB)
# Requirement already satisfied: matplotlib>=3.3.3 in /usr/local/lib/python3.10/dist-packages (from vsketch==1.0.0a0) (3.7.1)
# Collecting multiprocess>=0.70
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 13.9 MB/s eta 0:00:00
# Collecting vpype[all]==1.13
#   Downloading vpype-1.13.0-py3-none-any.whl (541 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.3/541.3 kB 44.4 MB/s eta 0:00:00
# Collecting cookiecutter>=2.1
#   Downloading cookiecutter-2.1.1-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: Shapely[vectorized]>=1.8.2 in /usr/local/lib/python3.10/dist-packages (from vsketch==1.0.0a0) (1.8.5.post1)
# Requirement already satisfied: scipy>=1.6 in /usr/local/lib/python3.10/dist-packages (from vpype[all]==1.13->vsketch==1.0.0a0) (1.10.1)
# Requirement already satisfied: click<8.2.0,>=8.0.1 in /usr/local/lib/python3.10/dist-packages (from vpype[all]==1.13->vsketch==1.0.0a0) (8.1.3)
# Requirement already satisfied: cachetools>=4.2.2 in /usr/local/lib/python3.10/dist-packages (from vpype[all]==1.13->vsketch==1.0.0a0) (5.3.0)
# Collecting svgelements>=1.6.10
#   Downloading svgelements-1.9.3-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.1/135.1 kB 10.3 MB/s eta 0:00:00
# Collecting asteval>=0.9.26
#   Downloading asteval-0.9.29-py3-none-any.whl (18 kB)
# Requirement already satisfied: tomli>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from vpype[all]==1.13->vsketch==1.0.0a0) (2.0.1)
# Collecting svgwrite<1.5,>=1.4
#   Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 6.6 MB/s eta 0:00:00
# Collecting glcontext>=2.3.2
#   Downloading glcontext-2.3.7-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 5.9 MB/s eta 0:00:00
# Collecting moderngl!=5.7.1,!=5.7.2,>=5.6.2
#   Downloading moderngl-5.8.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.5/281.5 kB 25.7 MB/s eta 0:00:00
# Collecting Pillow>=9.0.1
#   Downloading Pillow-9.5.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from cookiecutter>=2.1->vsketch==1.0.0a0) (2.29.0)
# Requirement already satisfied: python-slugify>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cookiecutter>=2.1->vsketch==1.0.0a0) (8.0.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from cookiecutter>=2.1->vsketch==1.0.0a0) (6.0)
# Collecting jinja2-time>=0.2.0
#   Downloading jinja2_time-0.2.0-py2.py3-none-any.whl (6.4 kB)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from cookiecutter>=2.1->vsketch==1.0.0a0) (3.1.2)
# Collecting binaryornot>=0.4.4
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->vsketch==1.0.0a0) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->vsketch==1.0.0a0) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->vsketch==1.0.0a0) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->vsketch==1.0.0a0) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->vsketch==1.0.0a0) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->vsketch==1.0.0a0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.3->vsketch==1.0.0a0) (3.0.9)
# Collecting dill>=0.3.6
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.9 MB/s eta 0:00:00
# Collecting shiboken6==6.5.0
#   Downloading shiboken6-6.5.0-cp37-abi3-manylinux_2_28_x86_64.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 kB 15.7 MB/s eta 0:00:00
# Collecting PySide6-Essentials==6.5.0
#   Downloading PySide6_Essentials-6.5.0-cp37-abi3-manylinux_2_28_x86_64.whl (80.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 MB 12.0 MB/s eta 0:00:00
# Collecting PySide6-Addons==6.5.0
#   Downloading PySide6_Addons-6.5.0-cp37-abi3-manylinux_2_28_x86_64.whl (125.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: anyio>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from watchfiles>=0.12->vsketch==1.0.0a0) (3.6.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles>=0.12->vsketch==1.0.0a0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles>=0.12->vsketch==1.0.0a0) (1.3.0)
# Requirement already satisfied: chardet>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from binaryornot>=0.4.4->cookiecutter>=2.1->vsketch==1.0.0a0) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4.0.0,>=2.7->cookiecutter>=2.1->vsketch==1.0.0a0) (2.1.2)
# Collecting arrow
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->vsketch==1.0.0a0) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify>=4.0.0->cookiecutter>=2.1->vsketch==1.0.0a0) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.0.0a0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.0.0a0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.0.0a0) (1.26.15)
# Building wheels for collected packages: vsketch
#   Building wheel for vsketch (pyproject.toml) ... done
#   Created wheel for vsketch: filename=vsketch-1.0.0a0-py3-none-any.whl size=67565 sha256=6b227199aa625a03a09b4d880e12fb101fb75cea6cad52159245faac46546780
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a4rvvm47/wheels/ae/cf/39/07c5cea9f662626ceca934c65eba2174064f72a471b416ca44
# Successfully built vsketch
# Installing collected packages: svgelements, glcontext, svgwrite, shiboken6, pnoise, Pillow, moderngl, dill, binaryornot, asteval, watchfiles, PySide6-Essentials, multiprocess, arrow, vpype, PySide6-Addons, jinja2-time, PySide6, cookiecutter, vsketch
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# Successfully installed Pillow-9.5.0 PySide6-6.5.0 PySide6-Addons-6.5.0 PySide6-Essentials-6.5.0 arrow-1.2.3 asteval-0.9.29 binaryornot-0.4.4 cookiecutter-2.1.1 dill-0.3.6 glcontext-2.3.7 jinja2-time-0.2.0 moderngl-5.8.2 multiprocess-0.70.14 pnoise-0.2.0 shiboken6-6.5.0 svgelements-1.9.3 svgwrite-1.4.3 vpype-1.13.0 vsketch-1.0.0a0 watchfiles-0.19.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/marceloprates/prettymaps.git
#   Cloning https://github.com/marceloprates/prettymaps.git to /tmp/pip-req-build-x6neg08s
#   Running command git clone --filter=blob:none --quiet https://github.com/marceloprates/prettymaps.git /tmp/pip-req-build-x6neg08s
#   Resolved https://github.com/marceloprates/prettymaps.git to commit dc90176911035d8e35a0c1e050d7cf87047358e8
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: osmnx==1.2.2 in /usr/local/lib/python3.10/dist-packages (from prettymaps==1.0.0) (1.2.2)
# Requirement already satisfied: Shapely<2.0,>=1.8 in /usr/local/lib/python3.10/dist-packages (from prettymaps==1.0.0) (1.8.5.post1)
# Requirement already satisfied: pyyaml==6.0.0 in /usr/local/lib/python3.10/dist-packages (from prettymaps==1.0.0) (6.0)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps==1.0.0) (2.29.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps==1.0.0) (3.1)
# Requirement already satisfied: Rtree>=1.0 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps==1.0.0) (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps==1.0.0) (1.22.4)
# Requirement already satisfied: pyproj>=3.3 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps==1.0.0) (3.5.0)
# Requirement already satisfied: geopandas>=0.11 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps==1.0.0) (0.12.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps==1.0.0) (1.5.3)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps==1.0.0) (3.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.11->osmnx==1.2.2->prettymaps==1.0.0) (23.1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.11->osmnx==1.2.2->prettymaps==1.0.0) (1.9.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps==1.0.0) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps==1.0.0) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps==1.0.0) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps==1.0.0) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps==1.0.0) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps==1.0.0) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps==1.0.0) (4.39.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->osmnx==1.2.2->prettymaps==1.0.0) (2022.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.3->osmnx==1.2.2->prettymaps==1.0.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx==1.2.2->prettymaps==1.0.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx==1.2.2->prettymaps==1.0.0) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx==1.2.2->prettymaps==1.0.0) (3.4)
# Requirement already satisfied: munch>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8->geopandas>=0.11->osmnx==1.2.2->prettymaps==1.0.0) (2.5.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8->geopandas>=0.11->osmnx==1.2.2->prettymaps==1.0.0) (8.1.3)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8->geopandas>=0.11->osmnx==1.2.2->prettymaps==1.0.0) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8->geopandas>=0.11->osmnx==1.2.2->prettymaps==1.0.0) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8->geopandas>=0.11->osmnx==1.2.2->prettymaps==1.0.0) (23.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->osmnx==1.2.2->prettymaps==1.0.0) (1.16.0)
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# --version option does not take a value
# --2023-04-28 08:10:02--  https://github.com/marceloprates/prettymaps/raw/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-04-28 08:10:03 ERROR 404: Not Found.

# %%
pip install prettymaps
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting prettymaps
#   Downloading prettymaps-1.0.0-py3-none-any.whl (36 kB)
# Collecting Shapely<2.0,>=1.8
#   Downloading Shapely-1.8.5.post1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 27.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml==6.0.0 in /usr/local/lib/python3.10/dist-packages (from prettymaps) (6.0)
# Collecting osmnx==1.2.2
#   Downloading osmnx-1.2.2-py2.py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 9.6 MB/s eta 0:00:00
# Collecting pyproj>=3.3
#   Downloading pyproj-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 79.3 MB/s eta 0:00:00
# Collecting geopandas>=0.11
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps) (1.5.3)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps) (3.7.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps) (3.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.2.2->prettymaps) (1.22.4)
# Collecting Rtree>=1.0
#   Downloading Rtree-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.9 MB/s eta 0:00:00
# Collecting requests>=2.28
#   Downloading requests-2.29.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.8 MB/s eta 0:00:00
# Collecting fiona>=1.8
#   Downloading Fiona-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 51.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas>=0.11->osmnx==1.2.2->prettymaps) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->osmnx==1.2.2->prettymaps) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->osmnx==1.2.2->prettymaps) (2022.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj>=3.3->osmnx==1.2.2->prettymaps) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx==1.2.2->prettymaps) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx==1.2.2->prettymaps) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->osmnx==1.2.2->prettymaps) (3.4)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8->geopandas>=0.11->osmnx==1.2.2->prettymaps) (23.1.0)
# Collecting munch>=2.3.2
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8->geopandas>=0.11->osmnx==1.2.2->prettymaps) (8.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->osmnx==1.2.2->prettymaps) (1.16.0)
# Installing collected packages: Shapely, Rtree, requests, pyproj, munch, cligj, click-plugins, fiona, geopandas, osmnx, prettymaps
#   Attempting uninstall: Shapely
#     Found existing installation: shapely 2.0.1
#     Uninstalling shapely-2.0.1:
#       Successfully uninstalled shapely-2.0.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
# Successfully installed Rtree-1.0.1 Shapely-1.8.5.post1 click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.3 geopandas-0.12.2 munch-2.5.0 osmnx-1.2.2 prettymaps-1.0.0 pyproj-3.5.0 requests-2.29.0

# %%
pip install descartes
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting descartes
#   Downloading descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from descartes) (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (4.39.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.22.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descartes) (9.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.16.0)
# Installing collected packages: descartes
# Successfully installed descartes-1.1.0

# %% [markdown]
# # Imports

# %%
# For local execution (does not require installing the library):
# %reload_ext autoreload
# %autoreload 2
import sys; sys.path.append('../')

# Prettymaps
from prettymaps import *
# Vsketch
try: 
  import vsketch
except:
  print("Vsketch import failed")
# OSMNX
import osmnx as ox
# Matplotlib-related
import matplotlib.font_manager as fm
from matplotlib import pyplot as plt
from descartes import PolygonPatch
# Shapely
from shapely.geometry import *
from shapely.affinity import *
from shapely.ops import unary_union

# %% [markdown]
# # Circle Plot

# %%
plot2 = plot(
     # Coordinates or location name
    (22.81601105093691, 89.56573584832017),
    circle = True,
    radius = 500,
    layers = {
        "green": {
            "tags": {
                "landuse": "grass",
                "natural": ["island", "wood"],
                "leisure": "park"
            }
        },
        "forest": {
            "tags": {
                "landuse": "forest"
            }
        },
        "water": {
            "tags": {
                "natural": ["water", "bay"]
            }
        },
        "parking": {
            "tags": {
                "amenity": "parking",
                "highway": "pedestrian",
                "man_made": "pier"
            }
        },
        "streets": {
            "width": {
                "motorway": 5,
                "trunk": 5,
                "primary": 4.5,
                "secondary": 4,
                "tertiary": 3.5,
                "residential": 3,
            }
        },
        "building": {
            "tags": {"building": True},
        },
    },
    style = {
        "background": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "hatch": "ooo...",
        },
        "perimeter": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "lw": 0,
            "hatch": "ooo...",
        },
        "green": {
            "fc": "#D0F1BF",
            "ec": "#2F3737",
            "lw": 1,
        },
        "forest": {
            "fc": "#64B96A",
            "ec": "#2F3737",
            "lw": 1,
        },
        "water": {
            "fc": "#a1e3ff",
            "ec": "#2F3737",
            "hatch": "ooo...",
            "hatch_c": "#85c9e6",
            "lw": 1,
        },
        "parking": {
            "fc": "#F2F4CB",
            "ec": "#2F3737",
            "lw": 1,
        },
        "streets": {
            "fc": "#2F3737",
            "ec": "#475657",
            "alpha": 1,
            "lw": 0,
        },
        "building": {
            "palette": [
                "#FFC857",
                "#E9724C",
                "#C5283D"
            ],
            "ec": "#2F3737",
            "lw": 0.5,
        }
    }
)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.

# %%
# Figure width and height
fig, ax = plt.subplots(figsize = (13, 13), constrained_layout = True)

layers2 = plot(
    # Coordinates or location name
    (22.81601105093691, 89.56573584832017), radius = 1500,
    ax = ax,
layers = {
        "green": {
            "tags": {
                "landuse": "grass",
                "natural": ["island", "wood"],
                "leisure": "park"
            }
        },
        "forest": {
            "tags": {
                "landuse": "forest"
            }
        },
        "water": {
            "tags": {
                "natural": ["water", "bay"]
            }
        },
        "parking": {
            "tags": {
                "amenity": "parking",
                "highway": "pedestrian",
                "man_made": "pier"
            }
        },
        "streets": {
            "width": {
                "motorway": 5,
                "trunk": 5,
                "primary": 4.5,
                "secondary": 4,
                "tertiary": 3.5,
                "residential": 3,
            }
        },
        "building": {
            "tags": {"building": True},
        },
    },
    style = {
        "background": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "hatch": "ooo...",
        },
        "perimeter": {
            "fc": "#F2F4CB",
            "ec": "#dadbc1",
            "lw": 0,
            "hatch": "ooo...",
        },
        "green": {
            "fc": "#D0F1BF",
            "ec": "#2F3737",
            "lw": 1,
        },
        "forest": {
            "fc": "#64B96A",
            "ec": "#2F3737",
            "lw": 1,
        },
        "water": {
            "fc": "#a1e3ff",
            "ec": "#2F3737",
            "hatch": "ooo...",
            "hatch_c": "#85c9e6",
            "lw": 1,
        },
        "parking": {
            "fc": "#F2F4CB",
            "ec": "#2F3737",
            "lw": 1,
        },
        "streets": {
            "fc": "#2F3737",
            "ec": "#475657",
            "alpha": 1,
            "lw": 0,
        },
        "building": {
            "palette": [
                "#FFC857",
                "#E9724C",
                "#C5283D"
            ],
            "ec": "#2F3737",
            "lw": 0.5,
        }
    }
)

plt.savefig('../prints/rome.png', dpi = 600)
#plt.savefig('../prints/rome.svg')
# Out:
# /usr/local/lib/python3.10/dist-packages/prettymaps/draw.py:979: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   plt.subplots_adjust(
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Ubuntu Mono' not found.
